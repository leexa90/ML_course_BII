# %% [markdown]
# ### 1. Load python modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn import datasets

# %% [markdown]
# ### 2. read dataset

# %%
iris = datasets.load_iris()
data = pd.DataFrame(iris['data'],columns=iris['feature_names'])
data['Class'] = iris.target

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [150 rows x 5 columns]

# %%
target_variable = 'Class'
explainatory_variables = ['Sepal_length_in_cm', 'Sepal_width_in_cm',
                          'Petal_length_in_cm','Petal_width_in_cm']

data_s = data[data['Class']=='Iris-setosa']
data_ve = data[data['Class']=='Iris-versicolor']
data_vi = data[data['Class']=='Iris-virginica']
# Out:
# /home/leexiongan/anaconda3/envs/python3.7/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
plt.plot(data_s['Sepal_length_in_cm'],data_s['Petal_length_in_cm'],'ro',label='setosa')
plt.plot(data_ve['Sepal_length_in_cm'],data_ve['Petal_length_in_cm'],'bo',label='versicolor')
plt.plot(data_vi['Sepal_length_in_cm'],data_vi['Petal_length_in_cm'],'go',label='virginica')
plt.xlabel('Sepal_length_in_cm')
plt.ylabel('Petal_length_in_cm')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/python3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sepal_length_in_cm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-26a5e0f2f65f> in <module>
# ----> 1 plt.plot(data_s['Sepal_length_in_cm'],data_s['Petal_length_in_cm'],'ro',label='setosa')
#       2 plt.plot(data_ve['Sepal_length_in_cm'],data_ve['Petal_length_in_cm'],'bo',label='versicolor')
#       3 plt.plot(data_vi['Sepal_length_in_cm'],data_vi['Petal_length_in_cm'],'go',label='virginica')
#       4 plt.xlabel('Sepal_length_in_cm')
#       5 plt.ylabel('Petal_length_in_cm')
#
# ~/anaconda3/envs/python3.7/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2973             if self.columns.nlevels > 1:
#    2974                 return self._getitem_multilevel(key)
# -> 2975             indexer = self.columns.get_loc(key)
#    2976             if is_integer(indexer):
#    2977                 indexer = [indexer]
#
# ~/anaconda3/envs/python3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
# -> 2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2893         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2894         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sepal_length_in_cm'

# %%
plt.plot(data_s['Sepal_width_in_cm'],data_s['Petal_width_in_cm'],'ro',label='setosa')
plt.plot(data_ve['Sepal_width_in_cm'],data_ve['Petal_width_in_cm'],'bo',label='versicolor')
plt.plot(data_vi['Sepal_width_in_cm'],data_vi['Petal_width_in_cm'],'go',label='virginica')
plt.xlabel('Sepal_width_in_cm')
plt.ylabel('Petal_width_in_cm')
plt.legend()
plt.show()
